# %%
import pandas as pd

# %%
#After over sampling the data, We have got the final data

data = pd.read_csv('/Users/abhisheksharma/Documents/Data Science Projects/Project-05-Dynamic-Pricing-Engine-for-E-Commerce/Data/Fashion_Retail_Sales_Combined.csv')
data
# Out:
#       customer_reference_id item_purchased  purchase_amount_(usd)  \
# 0                      4092     Polo Shirt                 200.00
# 1                      4108        Handbag                  50.00
# 2                      4020        Loafers                 110.00
# 3                      4071       Raincoat                 193.00
# 4                      4014       Tank Top                  99.00
# ...                     ...            ...                    ...
# 7050                   2414          Socks                 687.65
# 7051                   1137         Wallet                 150.49
# 7052                   3290         Wallet                   5.00
# 7053                   2379           Belt                  69.30
# 7054                   4579        T-Shirt                 225.04
#
#      date_purchase  review_rating  payment_method
# 0       2022-10-02            1.8     Credit Card
# 1       2022-10-02            2.1     Credit Card
# ...
